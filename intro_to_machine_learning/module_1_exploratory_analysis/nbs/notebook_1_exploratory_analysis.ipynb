# %% [markdown]
# # Module 1: Introduction to Exploratory Analysis

# %% [markdown]
# ## Overview

# %% [markdown]
# Welcome to the first notebook! In this notebook, we start exploring our [Kiva](https://www.kiva.org/) dataset. The goal of exploratory analysis is to summarize the main characteristics of a data set, with the belief that it may lead to new hypotheses that inform algorithm choice and experimentation. Exploratory analysis happens before formal modelling commences, and is extremely important for helping inform or sharpen your hypothesis.
#
# So what is a hypothesis? At the initial stage a [hypothesis](http://study.com/academy/lesson/what-is-a-hypothesis-definition-lesson-quiz.html) is an educational guess that can be tested. The main goal of exploratory analysis is helping us arrive at better hypotheses.

# %% [markdown]
# ## Step 1: Import and Merge Data

# %% [markdown]
# At the beginning of our notebooks we always import all the libraries we will use.

# %%
import pandas as pd
import numpy as np
from ggplot import *
import matplotlib.pyplot as plt
from datetime import datetime
import dateutil.parser
import seaborn
pd.options.display.mpl_style = 'default'

# the matplotlib inline command is important, it tells jupyter notebook to show the output of the cell for charts
# %matplotlib inline
# Out:
# C:\Users\g13k8050\Anaconda2\envs\moringa\lib\site-packages\ggplot\utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# C:\Users\g13k8050\Anaconda2\envs\moringa\lib\site-packages\ggplot\stats\smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# C:\Users\g13k8050\Anaconda2\envs\moringa\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# C:\Users\g13k8050\Anaconda2\envs\moringa\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# C:\Users\g13k8050\Anaconda2\envs\moringa\lib\site-packages\IPython\core\interactiveshell.py:2847: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# You are using Jupyter notebook to run your code. it is an incredibly versatile tool and we can tailor the configurations to suit our preferences. For example, in the cell below we tell Jupyter to output the results of all commands in a cell (the default is only to output the results of the last command). For more interesting and incredibly useful Jupyter tricks take a look at [this](https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/) blog post. Using Jupyter shortcuts will help you work faster. Some valuable shortcuts have been put together in [this](http://www.math.umassd.edu/~ahausknecht/aohWebsiteSpring2017/examples/pythonExamples/downloads/docs/JuypterKeyboardShortcutsV1Sp2016.pdf) great pdf.

# %%
# the command below means that the output of multiple commands in a cell will be output at once.

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# We use a pandas command to tailor how the data is presented in the command below. There are 76 columns in our final Kiva dataset. The default panda settings hide some of the columns. We make all columns visible by setting the display to 80.

# %%
# the command below tells jupyter to display up to 80 columns, this keeps everything visible
pd.set_option('display.max_columns', 80)
pd.set_option('expand_frame_repr', True)

# %% [markdown]
# We will use three main data sets: loans_full.csv, loans_details.csv, loans_partner_details.csv. These are all datasets KIVA makes publically available through its API. Wondering what an API is and how we pulled this data? Don't worry, you can learn all about it in the introduction to the KIVA APIs jupyter notebook we put together. It is available on the Delta Analytics GitHub.
#
# Let's start by talking a little about each data set:
#
# [loans_full](http://build.kiva.org/api#GET*|loans|search): contains all successful and expired loans made by KIVA in Kenya. KIVA does not make public loans that have defaulted in order to protect the privacy of those users.
#
# [loans_details](http://build.kiva.org/api#GET*|loans|:ids): contains many of the coumns as loans full. However, it also contains a comprehensive description of the lender.
#
# [loans_partner_details](http://build.kiva.org/api#GET*|partners|:ids): detailed performance metrics associated with each partner. Includes name of partner, rating of partner, amount lent to partner so far.
#
#
# When we import all out data sets we will also import a data dictionary with definitions of each field. We talk about the data dictionary more below.

# %% [markdown]
# We set the path below, you should change this path to whatever folder you save the data you download from the google drive [here](https://drive.google.com/drive/folders/0BzVUQjOmkeDIYnhCalBkRVRNY1k?usp=sharing) into.

# %%
#data_path = '../data'
data_path = '../../data'

# %% [markdown]
# We import all three data sets in the cell below.

# %%
loans_full=pd.read_csv(data_path+'/loans_full.csv', low_memory=False)
loans_details=pd.read_csv(data_path+'/loans_details.csv', low_memory=False)
loan_partner_details=pd.read_csv(data_path+'/loans_partner_details.csv', low_memory=False)

# %% [markdown]
# We will also import our data dictionary which contains the definition for each of the fields in the final data set we will use. Reference the data dictionary for important context about the data. It may be easier to open it as a csv file in your desktop.

# %%
kiva_data_dictionary=pd.read_csv(data_path+'/kiva_data_dictionary.csv')

# %%
kiva_data_dictionary.head(100)
# Out:
#         original_data_set                                     field_name  \
# 0              loans_full                                             id
# 1              loans_full                                          name
# 2              loans_full                                        gender
# 3              loans_full                                   description
# 4              loans_full                                         status
# 5              loans_full                                 fundedAmount
# 6              loans_full                                   basketAmount
# 7              loans_full                                         image
# 8              loans_full                                       activity
# 9              loans_full                                         sector
# 10             loans_full                                          use
# 11             loans_full                                       location
# 12             loans_full                                     partner_id
# 13             loans_full                                    posted_date
# 14             loans_full                       planned_expiration_date
# 15             loans_full                                    loan_amount
# 16             loans_full                                 borrower_count
# 17             loans_full                                   lender_count
# 18             loans_full                       bonus_credit_eligibility
# 19             loans_full                                           tags
# 20           loans_detail                                             id
# 21           loans_detail                                          name
# 22           loans_detail                                        gender
# 23           loans_detail                                   description
# 24           loans_detail                                         status
# 25           loans_detail                                 fundedAmount
# 26           loans_detail                                   basketAmount
# 27           loans_detail                                         image
# 28           loans_detail                                       activity
# 29           loans_detail                                         sector
# ..                    ...                                            ...
# 32           loans_detail                                     partner_id
# 33           loans_detail                                    posted_date
# 34           loans_detail                                    loan_amount
# 35           loans_detail                                   lender_count
# 36           loans_detail                       bonus_credit_eligibility
# 37           loans_detail                                           tags
# 38           loans_detail                                      borrowers
# 39           loans_detail                                          terms
# 40  loans_partner_details                                             id
# 41  loans_partner_details                                          name
# 42  loans_partner_details                                      "status":
# 43  loans_partner_details                                      "rating":
# 44  loans_partner_details                                        "image"
# 45  loans_partner_details                                   "start_date"
# 46  loans_partner_details                                    "countries"
# 47  loans_partner_details                             "delinquency_rate"
# 48  loans_partner_details                                 "default_rate"
# 49  loans_partner_details                          "total_amount_raised"
# 50  loans_partner_details                                 "loans_posted"
# 51  loans_partner_details                              "portfolio_yield"
# 52  loans_partner_details                               "profitability":
# 53  loans_partner_details                 "social_performance_strengths"
# 54  loans_partner_details                        "delinquency_rate_note"
# 55  loans_partner_details                            "default_rate_note"
# 56  loans_partner_details                         "portfolio_yield_note"
# 57  loans_partner_details                    "charges_fees_and_interest"
# 58  loans_partner_details  "average_loan_size_percent_per_capita_income"
# 59  loans_partner_details                           "loans_at_risk_rate"
# 60  loans_partner_details                  "currency_exchange_loss_rate"
# 61  loans_partner_details                                          "url"
#
#                              field_name_final_dataset  \
# 0                                                  id
# 1                                               name
# 2                                             gender
# 3                                        description
# 4                                              status
# 5                                      fundedAmount
# 6                                        basketAmount
# 7                                              image
# 8                                            activity
# 9                                              sector
# 10                                              use
# 11                                           location
# 12                                         partner_id
# 13                                        posted_date
# 14                           planned_expiration_date
# 15                                        loan_amount
# 16                                     borrower_count
# 17                                       lender_count
# 18                           bonus_credit_eligibility
# 19                                               tags
# 20                                                 id
# 21                                              name
# 22                                            gender
# 23                                       description
# 24                                             status
# 25                                     fundedAmount
# 26                                       basketAmount
# 27                                             image
# 28                                           activity
# 29                                             sector
# ..                                                ...
# 32                                         partner_id
# 33                                        posted_date
# 34                                        loan_amount
# 35                                       lender_count
# 36                           bonus_credit_eligibility
# 37                                               tags
# 38                                          borrowers
# 39                                              terms
# 40                                         partner_id
# 41                                       partner_name
# 42                                     partner_status
# 43                                     partner_rating
# 44                                      partner_image
# 45                                 partner_start_date
# 46                                  partner_countries
# 47                           partner_delinquency_rate
# 48                               partner_default_rate
# 49                        partner_total_amount_raised
# 50                               partner_loans_posted
# 51                            partner_portfolio_yield
# 52                              partner_profitability
# 53               partner_social_performance_strengths
# 54                      partner_delinquency_rate_note
# 55                          partner_default_rate_note
# 56                       partner_portfolio_yield_note
# 57                  partner_charges_fees_and_interest
# 58  partner_average_loan_size_percent_per_capita_i...
# 59                         partner_loans_at_risk_rate
# 60                partner_currency_exchange_loss_rate
# 61                                        partner_url
#
#                                           description  \
# 0                   Unique identifier for a Kiva loan
# 1   The name of the borrower or group receiving th...
# 2   The gender of the primary borrower OR majority...
# 3     The description of the loan profile in English.
# 4                          All possible loan statuses
# 5   ​The amount of the loan that has been purchase...
# 6   The amount of the unfunded loan that is sittin...
# 7                   The picture for this loan profile
# 8   The activity is a structured categorization of...
# 9   The sector is a more general classification of...
# 10  Text describing what the loan is to be used fo...
# 11  The physical location of the borrower and/or b...
# 12                                Kiva Id for partner
# 13         When the loan started fundraising on Kiva.
# 14  When the loan will expire if it is not fully f...
# 15       The amount of this loan, as shown to lenders
# 16  The number of borrowers participating in the loan
# 17  The number of borrowers participating in the loan
# 18  The loan is eligible for matching funds if a s...
# 19                        A list of tags on this loan
# 20                  Unique identifier for a Kiva loan
# 21  The name of the borrower or group receiving th...
# 22  The gender of the primary borrower OR majority...
# 23  The description of the loan profile in English...
# 24                         All possible loan statuses
# 25  ​The amount of the loan that has been purchase...
# 26  The amount of the unfunded loan that is sittin...
# 27  The picture for this loan profile, returns a d...
# 28  The activity is a structured categorization of...
# 29  The sector is a more general classification of...
# ..                                                ...
# 32                                Kiva Id for partner
# 33         When the loan started fundraising on Kiva.
# 34       The amount of this loan, as shown to lenders
# 35  The number of borrowers participating in the loan
# 36  The loan is eligible for matching funds if a s...
# 37                        A list of tags on this loan
# 38  Information about the borrowers associated wit...
# 39  Information about terms of the loand, returns ...
# 40               Unique identifier for a Kiva partner
# 41         The name of the microfinance field partner
# 42  The status of the partner’s relationship with ...
# 43                          Field Partner Risk Rating
# 44  Field Partner logo, returns dictionary with im...
# 45    When the partner started offering loans on kiva
# 46  The physical location of the borrower and/or b...
# 47  Kiva defines a partner's delinquency (arrears)...
# 48  the percentage of Kiva loans being paid back b...
# 49  The total of all loans made by the partner on ...
# 50    The number of loans made by the partner on Kiva
# 51  Kiva uses a calculation called "portfolio yiel...
# 52   an indication of a Field Partner's profitability
# 53  Returns a list of Social performance types tha...
# 54  A Kiva-supplied note that is shown in lieu of ...
# 55  A Kiva-supplied note that is shown in lieu of ...
# 56  A Kiva-supplied note that is shown in lieu of ...
# 57  A true/false property for whether the partner ...
# 58  A ratio of the partner's average loan size to ...
# 59  A decimal representing the percentage of the p...
# 60  Kiva calculates the Currency Exchange Loss Rat...
# 61                      Partner's web address or link
#
#                                      additional_notes
# 0                                                 Int
# 1                                              String
# 2                  possible values are male or female
# 3                                              String
# 4   The public dataset does not reveal defaulted l...
# 5                            ​The dollar amount in US
# 6                            ​The dollar amount in US
# 7                                               Image
# 8   A property of loan which is more descriptive t...
# 9   A sector is a broad category for a loan, e.g. ...
# 10                                             String
# 11  Kiva Geocode = city, state, postalCode, llatit...
# 12                                                int
# 13  Returns a UTC datetime in ISO8601 format. As a...
# 14  Returns a UTC datetime in ISO8601 format. As a...
# 15                           The dollar amount in USD
# 16                                                Int
# 17                                                Int
# 18                                            Boolean
# 19                                             String
# 20                                                Int
# 21                                             String
# 22                 possible values are male or female
# 23                       includes fields: languages:
# 24  The public dataset does not reveal defaulted l...
# 25                           ​The dollar amount in US
# 26                           ​The dollar amount in US
# 27                                              Image
# 28  A property of loan which is more descriptive t...
# 29  A sector is a broad category for a loan, e.g. ...
# ..                                                ...
# 32                                                int
# 33  Returns a UTC datetime in ISO8601 format. As a...
# 34                           The dollar amount in USD
# 35                                                Int
# 36                                            Boolean
# 37                                             String
# 38                                                NaN
# 39  "local_payments", "scheduled_paymnets" and "pa...
# 40                                                Int
# 41                                             String
# 42                                             String
# 43                                  Float as a string
# 44                                              Image
# 45  Returns a UTC datetime in ISO8601 format. As a...
# 46  Kiva Geocode = city, state, postalCode, llatit...
# 47                                              Float
# 48                                              Float
# 49                                                Int
# 50                                                Int
# 51                                              Float
# 52                                              Float
# 53                                              Array
# 54  is an empty string to be shown user w/o appror...
# 55  is an empty string to be shown user w/o appror...
# 56  is an empty string to be shown user w/o appror...
# 57                                            Boolean
# 58                                              Float
# 59                                                NaN
# 60                                              Float
# 61                                             String
#
# [62 rows x 5 columns]

# %% [markdown]
# In the cell below we perform a very important piece of code. We merge our datasets together in order to have a single final dataset. You will often have to merge/join datasets because many databases are relational databases. This means data is stored in tables that can be accessed and/or reassembled in many different ways (you can learn more [here](http://searchsqlserver.techtarget.com/definition/relational-database)). This has important benefits:
# - allowing the flexible addition of new data without exsisting tables needing to be altered
# - limiting the size of the data we store
#
# Instead of having one single huge table in our database, we have many different tables that we can piece together as needed. This act of piecing together datasets is called a merge.

# %% [markdown]
# So when does it make sense to merge data?
#
# In order to merge data, you need to have a columns in both datasets that have shared values. The columns you use to perform the join are called "join keys".
#
# For example, the join key in both loans_full and loans_details is the id. This is the unique identifier for a loan and is shared between both datasets. In both datasets this is a unique key, which means we only expect a single row for every row (no duplicates).
#
# The join key between loans_full and loans_partner_details is the partner_id. This is unique in loans_partner_details (every row is a unique partner_id), but is not unique in loans_full since many rows (loans) belong to the same partner. We can show that is not unique below by doing a value_count of the number of loans that belong to each partner_id in loans_full. We show the top 10 loan partners by size, you can see that the top loan partner '133' has been involved in 28,560 loans. When we join loans_full to loans_partner_details we can associate a name with each number identifier, and it will be a lot more interesting.

# %%
loans_full.partner_id.value_counts().nlargest(10)
# Out:
# 133.0    28560
# 164.0    21552
# 138.0    18101
# 156.0    18081
# 202.0    10356
# 142.0     5922
# 388.0     3210
# 203.0     2987
# 386.0     2388
# 6.0       1102
# Name: partner_id, dtype: int64

# %%
loans_full['partner_id'].value_counts().nlargest(10)
# Out:
# 133.0    28560
# 164.0    21552
# 138.0    18101
# 156.0    18081
# 202.0    10356
# 142.0     5922
# 388.0     3210
# 203.0     2987
# 386.0     2388
# 6.0       1102
# Name: partner_id, dtype: int64

# %% [markdown]
# Back to how to join! There are actually a few different types of merges, and the type of merge you choose depends upon what data you want to keep in your final data set.
#
# There are two fantastic blog posts which do a great job explaining the different types of merges [here](http://www.datacarpentry.org/python-ecology-lesson/04-merging-data/) and [here](https://blog.codinghorror.com/a-visual-explanation-of-sql-joins/). We will reference the language in both posts below to add intuition.

# %% [markdown]
# **inner join**
#
# We will be using an inner join to join loans_full and loans_details because we only want the rows that match in both the original dataframes.
#
# Inner joins yield a DataFrame that contains only rows where the value being joins exists in BOTH tables. The venn diagram below shows what is kept from both data frames.
#
# ![Visual of an inner join](module_1_images/inner_join.png)
#
# Below we test it in python using our two datasets, loans_full and loan_difference.

# %% [markdown]
# loans_full and loan_difference contain many columns that are duplicates (exsist in both). There is no need to merge all the columns so we start out by figuring out what additional columns ARE in loans_details that ARE NOT in loans_full. We can see below that only borrower_count is additional, so we only merge these two columns.

# %%
loans_details.head(1)
# Out:
#    Unnamed: 0 activity  basket_amount  bonus_credit_eligibility  \
# 0           0  Farming            0.0                     False
#
#                                            borrowers  \
# 0  [{'first_name': 'Evaline', 'last_name': '', 'g...
#
#    currency_exchange_loss_amount description.languages  \
# 0                            NaN                ['en']
#
#                                 description.texts.en description.texts.es  \
# 0  Evaline is a married lady aged 44 years old an...                  NaN
#
#   description.texts.fr description.texts.ru  funded_amount funded_date  \
# 0                  NaN                  NaN              0         NaN
#
#         id  image.id  image.template_id  journal_totals.bulkEntries  \
# 0  1291548   2516002                  1                           0
#
#    journal_totals.entries  lender_count  loan_amount location.country  \
# 0                       0             0          500            Kenya
#
#   location.country_code location.geo.level   location.geo.pairs  \
# 0                    KE               town  -0.583333 35.183333
#
#   location.geo.type location.town     name  partner_id payments  \
# 0             point        litein  Evaline       386.0       []
#
#   planned_expiration_date           posted_date       sector       status  \
# 0    2017-06-08T00:40:03Z  2017-05-09T00:40:03Z  Agriculture  fundraising
#
#                                                 tags  terms.disbursal_amount  \
# 0  [{'name': '#Woman Owned Biz'}, {'name': '#Pare...                 50000.0
#
#   terms.disbursal_currency  terms.disbursal_date  terms.loan_amount  \
# 0                      KES  2017-04-03T07:00:00Z                500
#
#                                 terms.local_payments  \
# 0  [{'due_date': '2017-05-10T07:00:00Z', 'amount'...
#
#   terms.loss_liability.currency_exchange  \
# 0                                 shared
#
#    terms.loss_liability.currency_exchange_coverage_rate  \
# 0                                                0.1
#
#   terms.loss_liability.nonpayment terms.repayment_interval  \
# 0                          lender                  Monthly
#
#    terms.repayment_term                           terms.scheduled_payments  \
# 0                    14  [{'due_date': '2017-07-01T07:00:00Z', 'amount'...
#
#   themes translator.byline  translator.image  \
# 0    NaN      Julie Keaton          892591.0
#
#                                                  use  video.id  \
# 0  to purchase more tea leaves to sell to the tea...       NaN
#
#    video.thumbnailImageId video.title video.youtubeId
# 0                     NaN         NaN             NaN

# %%
loans_full.head(1)
# Out:
#    Unnamed: 0 activity  basket_amount  bonus_credit_eligibility  \
# 0           0  Farming            0.0                     False
#
#    borrower_count  currency_exchange_loss_amount description.languages  \
# 0               1                            NaN                ['en']
#
#    funded_amount       id  image.id  image.template_id  lender_count  \
# 0              0  1291548   2516002                  1             0
#
#    loan_amount location.country location.country_code location.geo.level  \
# 0          500            Kenya                    KE               town
#
#     location.geo.pairs location.geo.type location.town     name  partner_id  \
# 0  -0.583333 35.183333             point        litein  Evaline       386.0
#
#   planned_expiration_date           posted_date       sector       status  \
# 0    2017-06-08T00:40:03Z  2017-05-09T00:40:03Z  Agriculture  fundraising
#
#                                                 tags themes  \
# 0  [{'name': '#Woman Owned Biz'}, {'name': '#Pare...    NaN
#
#                                                  use  video.id  \
# 0  to purchase more tea leaves to sell to the tea...       NaN
#
#    video.thumbnailImageId video.title video.youtubeId
# 0                     NaN         NaN             NaN

# %%
additional_columns = loans_full.columns.difference(loans_details.columns).tolist() + ['id']
print(additional_columns)
# Out:
# ['borrower_count', 'id']

# %% [markdown]
# Finally, we are ready to merge. We do not need to specify inner join since it is the default option. However, we do need to specify what are the join keys in each data set. In this case the naming is the same in both datasets, so we specify 'id' as the join key for the loans_details data set and 'id' for the loans_full data set.

# %%
df = loans_details.merge(loans_full[['borrower_count', 'id']], left_on='id', right_on='id')

# %% [markdown]
# You can take a look at the output below and confirm that borrow_count is now there. The new dataframe only contains loans that are in both loans_full and loans_details.

# %%
# The sample() function takes a random sample from the specified data frame. 
df.sample(3)
# Out:
#         Unnamed: 0               activity  basket_amount  \
# 21584        21570  Food Production/Sales            NaN
# 121740      121682                  Dairy            NaN
# 4841          4841    Home Products Sales            NaN
#
#         bonus_credit_eligibility  \
# 21584                       True
# 121740                     False
# 4841                       False
#
#                                                 borrowers  \
# 21584   [{'first_name': ' \tMwasiti ', 'last_name': ''...
# 121740  [{'first_name': 'Anonymous', 'last_name': '', ...
# 4841    [{'first_name': 'Santana', 'last_name': '', 'g...
#
#         currency_exchange_loss_amount description.languages  \
# 21584                             NaN                ['en']
# 121740                            NaN                ['en']
# 4841                              NaN                ['en']
#
#                                      description.texts.en  \
# 21584   Mwasiti is a married  woman with two children,...
# 121740                                                NaN
# 4841    Santana is 37 years old, single, and has one c...
#
#        description.texts.es description.texts.fr description.texts.ru  \
# 21584                   NaN                  NaN                  NaN
# 121740                  NaN                  NaN                  NaN
# 4841                    NaN                  NaN                  NaN
#
#         funded_amount           funded_date       id  image.id  \
# 21584             200  2016-05-25T15:08:50Z  1072452   2185652
# 121740           1050  2010-04-25T21:19:23Z   195360    726677
# 4841              300  2017-03-08T17:43:08Z  1248046   2450140
#
#         image.template_id  journal_totals.bulkEntries  journal_totals.entries  \
# 21584                   1                           0                       0
# 121740                  1                           0                       0
# 4841                    1                           0                       0
#
#         lender_count  loan_amount location.country location.country_code  \
# 21584              8          200            Kenya                    KE
# 121740            17         1050            Kenya                    KE
# 4841               9          300            Kenya                    KE
#
#        location.geo.level  location.geo.pairs location.geo.type location.town  \
# 21584                town                1 38             point     Msambweni
# 121740            country                1 38             point           NaN
# 4841                 town  0.516667 35.283333             point       Eldoret
#
#              name  partner_id payments planned_expiration_date  \
# 21584     Mwasiti       164.0       []    2016-06-23T20:50:03Z
# 121740  Anonymous       156.0       []                     NaN
# 4841      Santana       133.0       []    2017-04-04T20:10:04Z
#
#                  posted_date       sector  status  \
# 21584   2016-05-24T20:50:03Z         Food  funded
# 121740  2010-04-23T08:40:03Z  Agriculture  funded
# 4841    2017-03-05T21:10:04Z       Retail  funded
#
#                                                      tags  \
# 21584                                                  []
# 121740                                                 []
# 4841    [{'name': '#Single Parent'}, {'name': '#School...
#
#         terms.disbursal_amount terms.disbursal_currency  terms.disbursal_date  \
# 21584                  20000.0                      KES  2016-05-19T07:00:00Z
# 121740                 80000.0                      KES  2010-04-21T07:00:00Z
# 4841                   30000.0                      KES  2017-02-09T08:00:00Z
#
#         terms.loan_amount terms.local_payments  \
# 21584                 200                   []
# 121740               1050                   []
# 4841                  300                   []
#
#        terms.loss_liability.currency_exchange  \
# 21584                                  shared
# 121740                                 shared
# 4841                                   shared
#
#         terms.loss_liability.currency_exchange_coverage_rate  \
# 21584                                                 0.1
# 121740                                                0.2
# 4841                                                  0.1
#
#        terms.loss_liability.nonpayment terms.repayment_interval  \
# 21584                           lender                      NaN
# 121740                          lender                      NaN
# 4841                            lender                      NaN
#
#         terms.repayment_term terms.scheduled_payments themes  \
# 21584                     14                       []    NaN
# 121740                    14                       []    NaN
# 4841                      11                       []    NaN
#
#        translator.byline  translator.image  \
# 21584         Tim Gibson         1632475.0
# 121740    Kevin Chaissan               NaN
# 4841       Lorne Warwick          215175.0
#
#                                                       use  video.id  \
# 21584   to purchase a stock of wheat flour, sugar, pea...       NaN
# 121740                                                NaN       NaN
# 4841              to purchase more home products to sell.       NaN
#
#         video.thumbnailImageId video.title video.youtubeId  borrower_count
# 21584                      NaN         NaN             NaN               1
# 121740                     NaN         NaN             NaN               1
# 4841                       NaN         NaN             NaN               1

# %% [markdown]
# **left join**
#
# Now we perform a different type of merge in order to incorporate the loan_partner_details dataset. This merge is called a left join. The description below is directly from [this](http://www.datacarpentry.org/python-ecology-lesson/04-merging-data/) blog post.
#
# Like an inner join, a **left join** uses join keys to combine two DataFrames. Unlike an inner join, a left join will return all of the rows from the left DataFrame, even those rows whose join key(s) do not have values in the right DataFrame. Rows in the left DataFrame that are missing values for the join key(s) in the right DataFrame will simply have null (i.e., NaN or None) values for those columns in the resulting joined DataFrame.
#
# Note: a left join will still discard rows from the right DataFrame that do not have values for the join key(s) in the left DataFrame.
#
# The venn diagram below shows what is kept from both data frames.
#
# ![Visual of an left join](module_1_images/left_join.png)
#
# What this means is that we will keep our entire df dataframe, and we will only pull in data from loan_partner_details of the partner_id for partner_id listed in df. We will discard everything else. The code below goes through how this is done.

# %% [markdown]
# In the cell below, we rename all the columns in loans_partner_details with the prefix partner in order to avoid confusion once we merge. Then we take list all columns that are in loans_partner_details but not in df. These are the new columns we want to merge. Finally, we do a left join.
#
# A left join is performed in pandas by calling the same merge function used for inner join, but using the how='left' argument.

# %%
new_names = [(i,'partner_'+i) for i in loan_partner_details.iloc[:, 1:].columns.values]
loan_partner_details.rename(columns = dict(new_names), inplace=True)

# %%
additional_columns = loan_partner_details.columns.difference(df.columns).tolist() + ['partner_id']
print(additional_columns)
# Out:
# ['partner_average_loan_size_percent_per_capita_income', 'partner_charges_fees_and_interest', 'partner_countries', 'partner_currency_exchange_loss_rate', 'partner_default_rate', 'partner_default_rate_note', 'partner_delinquency_rate', 'partner_delinquency_rate_note', 'partner_image.id', 'partner_image.template_id', 'partner_loans_at_risk_rate', 'partner_loans_posted', 'partner_name', 'partner_portfolio_yield', 'partner_portfolio_yield_note', 'partner_profitability', 'partner_rating', 'partner_social_performance_strengths', 'partner_start_date', 'partner_status', 'partner_total_amount_raised', 'partner_url', 'partner_id']

# %%
df = df.merge(loan_partner_details[['partner_average_loan_size_percent_per_capita_income', 
                                    'partner_charges_fees_and_interest', 'partner_countries', 
                                    'partner_currency_exchange_loss_rate', 'partner_default_rate', 
                                    'partner_default_rate_note', 'partner_delinquency_rate', 'partner_delinquency_rate_note', 
                                    'partner_image.id', 'partner_image.template_id', 'partner_loans_at_risk_rate', 'partner_loans_posted', 
                                    'partner_name', 'partner_portfolio_yield', 'partner_portfolio_yield_note', 'partner_profitability', 
                                    'partner_rating', 'partner_social_performance_strengths', 'partner_start_date', 'partner_status', 
                                    'partner_total_amount_raised', 'partner_url', 'partner_id']], how='left', left_on='partner_id', right_on='partner_id')

# %% [markdown]
# We have successully merged our dataframe and we are ready to get started with our exploratory analysis. For completness, below is a short description of the other join types you are likely to come across as you work with data more.
#
# **full join**
#
# ![Visual of an full join](module_1_images/full_join.png)
#
# A full join returns all rows from both datasets even if there is no match. All records will be kept so this join is used when we do not want to lose any data but want to see what rows match.
# Invoked by passing how='outer' as an argument.
#
# **right join**
#
# A right join is the same concept as the left join except it keeps all rows in the right data set rather than the left. Invoked by passing how='right' as an argument.

# %% [markdown]
# We don't want to have to join all our datsets everytime we get started so we save our work to our data folder using the command below.

# %%
df.to_csv('../../data/df.csv')

# %% [markdown]
# ## Step 2:  Data Cleaning & Creating New Variables

# %%
df.head()
# Out:
#    Unnamed: 0          activity  basket_amount  bonus_credit_eligibility  \
# 0           0           Farming            0.0                     False
# 1           1  Furniture Making            0.0                     False
# 2           2       Home Energy            0.0                     False
# 3           3     Used Clothing            0.0                     False
# 4           4           Farming            0.0                     False
#
#                                            borrowers  \
# 0  [{'first_name': 'Evaline', 'last_name': '', 'g...
# 1  [{'first_name': 'Julias', 'last_name': '', 'ge...
# 2  [{'first_name': 'Rose', 'last_name': '', 'gend...
# 3  [{'first_name': 'Jane', 'last_name': '', 'gend...
# 4  [{'first_name': 'Alice', 'last_name': '', 'gen...
#
#    currency_exchange_loss_amount description.languages  \
# 0                            NaN                ['en']
# 1                            NaN                ['en']
# 2                            NaN                ['en']
# 3                            NaN                ['en']
# 4                            NaN                ['en']
#
#                                 description.texts.en description.texts.es  \
# 0  Evaline is a married lady aged 44 years old an...                  NaN
# 1  Aged 42 years is a man by the name of Julias. ...                  NaN
# 2  Hello Kiva Community! <br /><br />Meet Rose, w...                  NaN
# 3  Jane was born in the 1980, and she is happily ...                  NaN
# 4  Alice (the woman pictured above in her small s...                  NaN
#
#   description.texts.fr description.texts.ru  funded_amount funded_date  \
# 0                  NaN                  NaN              0         NaN
# 1                  NaN                  NaN              0         NaN
# 2                  NaN                  NaN             50         NaN
# 3                  NaN                  NaN              0         NaN
# 4                  NaN                  NaN              0         NaN
#
#         id  image.id  image.template_id  journal_totals.bulkEntries  \
# 0  1291548   2516002                  1                           0
# 1  1291532   2515992                  1                           0
# 2  1291530   2515991                  1                           0
# 3  1291525   2515986                  1                           0
# 4  1291518   2515975                  1                           0
#
#    journal_totals.entries  lender_count  loan_amount location.country  \
# 0                       0             0          500            Kenya
# 1                       0             0          500            Kenya
# 2                       0             2           75            Kenya
# 3                       0             0          500            Kenya
# 4                       0             0          400            Kenya
#
#   location.country_code location.geo.level   location.geo.pairs  \
# 0                    KE               town  -0.583333 35.183333
# 1                    KE               town   0.566667 34.566667
# 2                    KE               town   0.516667 35.283333
# 3                    KE               town   0.566667 34.566667
# 4                    KE               town                 1 38
#
#   location.geo.type location.town     name partner_id payments  \
# 0             point        litein  Evaline        386       []
# 1             point       Bungoma   Julias        386       []
# 2             point       Eldoret     Rose        156       []
# 3             point       Bungoma     Jane        386       []
# 4             point   Nandi Hills    Alice        156       []
#
#   planned_expiration_date           posted_date         sector       status  \
# 0    2017-06-08T00:40:03Z  2017-05-09T00:40:03Z    Agriculture  fundraising
# 1    2017-06-08T00:30:05Z  2017-05-09T00:30:05Z  Manufacturing  fundraising
# 2    2017-06-08T00:30:03Z  2017-05-09T00:30:04Z   Personal Use  fundraising
# 3    2017-06-08T00:20:04Z  2017-05-09T00:20:04Z       Clothing  fundraising
# 4    2017-06-08T00:20:03Z  2017-05-09T00:20:03Z    Agriculture  fundraising
#
#                                                 tags  terms.disbursal_amount  \
# 0  [{'name': '#Woman Owned Biz'}, {'name': '#Pare...                 50000.0
# 1                                                 []                 50000.0
# 2  [{'name': '#Eco-friendly'}, {'name': '#Technol...                  6000.0
# 3                        [{'name': '#Eco-friendly'}]                 50000.0
# 4                     [{'name': '#Woman Owned Biz'}]                 40000.0
#
#   terms.disbursal_currency  terms.disbursal_date  terms.loan_amount  \
# 0                      KES  2017-04-03T07:00:00Z                500
# 1                      KES  2017-04-03T07:00:00Z                500
# 2                      KES  2017-04-28T07:00:00Z                 75
# 3                      KES  2017-04-03T07:00:00Z                500
# 4                      KES  2017-05-27T07:00:00Z                400
#
#                                 terms.local_payments  \
# 0  [{'due_date': '2017-05-10T07:00:00Z', 'amount'...
# 1  [{'due_date': '2017-05-09T07:00:00Z', 'amount'...
# 2  [{'due_date': '2017-05-14T07:00:00Z', 'amount'...
# 3  [{'due_date': '2017-05-08T07:00:00Z', 'amount'...
# 4  [{'due_date': '2017-05-27T07:00:00Z', 'amount'...
#
#   terms.loss_liability.currency_exchange  \
# 0                                 shared
# 1                                 shared
# 2                                 shared
# 3                                 shared
# 4                                 shared
#
#    terms.loss_liability.currency_exchange_coverage_rate  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#   terms.loss_liability.nonpayment terms.repayment_interval  \
# 0                          lender                  Monthly
# 1                          lender                  Monthly
# 2                          lender                  Monthly
# 3                          lender                  Monthly
# 4                          lender                  Monthly
#
#    terms.repayment_term                           terms.scheduled_payments  \
# 0                    14  [{'due_date': '2017-07-01T07:00:00Z', 'amount'...
# 1                    14  [{'due_date': '2017-07-01T07:00:00Z', 'amount'...
# 2                    14  [{'due_date': '2017-07-01T07:00:00Z', 'amount'...
# 3                    14  [{'due_date': '2017-07-01T07:00:00Z', 'amount'...
# 4                    13  [{'due_date': '2017-07-01T07:00:00Z', 'amount'...
#
#                             themes translator.byline  translator.image  \
# 0                              NaN      Julie Keaton          892591.0
# 1                              NaN      Morena Calvo         1832928.0
# 2  ['Green', 'Earth Day Campaign']      Julie Keaton          892591.0
# 3                              NaN      Julie Keaton          892591.0
# 4              ['Rural Exclusion']               NaN               NaN
#
#                                                  use  video.id  \
# 0  to purchase more tea leaves to sell to the tea...       NaN
# 1  to buy timber to make more furniture for his e...       NaN
# 2                            to buy a solar lantern.       NaN
# 3  to buy more clothes to meet the needs and tast...       NaN
# 4  to buy farming inputs (fertilizers, pesticides...       NaN
#
#    video.thumbnailImageId video.title video.youtubeId  borrower_count  \
# 0                     NaN         NaN             NaN               1
# 1                     NaN         NaN             NaN               1
# 2                     NaN         NaN             NaN               1
# 3                     NaN         NaN             NaN               1
# 4                     NaN         NaN             NaN               1
#
#    partner_average_loan_size_percent_per_capita_income  \
# 0                                                0.0
# 1                                                0.0
# 2                                               49.6
# 3                                                0.0
# 4                                               49.6
#
#   partner_charges_fees_and_interest  \
# 0                              True
# 1                              True
# 2                              True
# 3                              True
# 4                              True
#
#                                    partner_countries  \
# 0  [{'iso_code': 'KE', 'region': 'Africa', 'name'...
# 1  [{'iso_code': 'KE', 'region': 'Africa', 'name'...
# 2  [{'iso_code': 'KE', 'region': 'Africa', 'name'...
# 3  [{'iso_code': 'KE', 'region': 'Africa', 'name'...
# 4  [{'iso_code': 'KE', 'region': 'Africa', 'name'...
#
#    partner_currency_exchange_loss_rate  partner_default_rate  \
# 0                             0.120642              0.000000
# 1                             0.120642              0.000000
# 2                             0.431935              2.575299
# 3                             0.120642              0.000000
# 4                             0.431935              2.575299
#
#    partner_default_rate_note  partner_delinquency_rate  \
# 0                        NaN                  7.017031
# 1                        NaN                  7.017031
# 2                        NaN                  2.536684
# 3                        NaN                  7.017031
# 4                        NaN                  2.536684
#
#    partner_delinquency_rate_note  partner_image.id  partner_image.template_id  \
# 0                            NaN         1592272.0                        1.0
# 1                            NaN         1592272.0                        1.0
# 2                            NaN         1834079.0                        1.0
# 3                            NaN         1592272.0                        1.0
# 4                            NaN         1834079.0                        1.0
#
#    partner_loans_at_risk_rate  partner_loans_posted   partner_name  \
# 0                   21.165398                1948.0    Kenya ECLOF
# 1                   21.165398                1948.0    Kenya ECLOF
# 2                   24.200354               18150.0  Juhudi Kilimo
# 3                   21.165398                1948.0    Kenya ECLOF
# 4                   24.200354               18150.0  Juhudi Kilimo
#
#    partner_portfolio_yield  partner_portfolio_yield_note  \
# 0                     40.3                           NaN
# 1                     40.3                           NaN
# 2                     33.0                           NaN
# 3                     40.3                           NaN
# 4                     33.0                           NaN
#
#    partner_profitability partner_rating  \
# 0                   2.54            2.0
# 1                   2.54            2.0
# 2                  -7.10            2.0
# 3                   2.54            2.0
# 4                  -7.10            2.0
#
#                 partner_social_performance_strengths    partner_start_date  \
# 0  [{'id': 3, 'name': 'Client Voice', 'descriptio...  2014-05-29T13:30:02Z
# 1  [{'id': 3, 'name': 'Client Voice', 'descriptio...  2014-05-29T13:30:02Z
# 2  [{'id': 1, 'name': 'Anti-Poverty Focus', 'desc...  2010-01-15T20:20:17Z
# 3  [{'id': 3, 'name': 'Client Voice', 'descriptio...  2014-05-29T13:30:02Z
# 4  [{'id': 1, 'name': 'Anti-Poverty Focus', 'desc...  2010-01-15T20:20:17Z
#
#   partner_status  partner_total_amount_raised                   partner_url
# 0         active                     863375.0   http://www.eclof-kenya.org/
# 1         active                     863375.0   http://www.eclof-kenya.org/
# 2         active                    7705925.0  http://www.juhudikilimo.com/
# 3         active                     863375.0   http://www.eclof-kenya.org/
# 4         active                    7705925.0  http://www.juhudikilimo.com/

# %%
df=pd.read_csv(data_path+'/df.csv', low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14858)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 31: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-29-2e3e71f66135> in <module>()
# ----> 1 df=pd.read_csv(data_path+'/df.csv', low_memory=False)
#
# C:\Users\g13k8050\Anaconda2\envs\moringa\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# C:\Users\g13k8050\Anaconda2\envs\moringa\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     409
#     410     try:
# --> 411         data = parser.read(nrows)
#     412     finally:
#     413         parser.close()
#
# C:\Users\g13k8050\Anaconda2\envs\moringa\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#     980                 raise ValueError('skipfooter not supported for iteration')
#     981
# --> 982         ret = self._engine.read(nrows)
#     983
#     984         if self.options.get('as_recarray'):
#
# C:\Users\g13k8050\Anaconda2\envs\moringa\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1717     def read(self, nrows=None):
#    1718         try:
# -> 1719             data = self._reader.read(nrows)
#    1720         except StopIteration:
#    1721             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read (pandas\_libs\parsers.c:10885)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows (pandas\_libs\parsers.c:12175)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data (pandas\_libs\parsers.c:14136)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14972)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 31: invalid start byte

# %% [markdown]
# In the cell below, we take a random sample of 3 rows to get a feel for the data.

# %%
df.sample(3)
# Out:
#         Unnamed: 0              activity  basket_amount  \
# 41588        41568         General Store            NaN
# 43731        43711  Motorcycle Transport            NaN
# 119173      119115    Education provider            NaN
#
#         bonus_credit_eligibility  \
# 41588                      False
# 43731                      False
# 119173                     False
#
#                                                 borrowers  \
# 41588   [{'first_name': 'Irene', 'last_name': '', 'gen...
# 43731   [{'first_name': 'Geoffrey ', 'last_name': '', ...
# 119173  [{'first_name': ' Florence Ilamwenya ', 'last_...
#
#         currency_exchange_loss_amount description.languages  \
# 41588                             NaN                ['en']
# 43731                             NaN                ['en']
# 119173                           2.45                ['en']
#
#                                      description.texts.en  \
# 41588   Irene is 29 years old, married to George, and ...
# 43731   Geoffrey is 27 years old, married to Josephine...
# 119173  Florence Ilamwenya W., 48 years old, is a skil...
#
#        description.texts.es description.texts.fr description.texts.ru  \
# 41588                   NaN                  NaN                  NaN
# 43731                   NaN                  NaN                  NaN
# 119173                  NaN                  NaN                  NaN
#
#         funded_amount           funded_date      id  image.id  \
# 41588             275  2015-07-13T15:47:39Z  899659   1895353
# 43731             100                   NaN  885169   1872549
# 119173            325  2010-10-12T20:54:20Z  237968    616350
#
#         image.template_id  journal_totals.bulkEntries  journal_totals.entries  \
# 41588                   1                           0                       0
# 43731                   1                           0                       0
# 119173                  1                           0                       0
#
#         lender_count  loan_amount location.country location.country_code  \
# 41588              6          275            Kenya                    KE
# 43731              4          275            Kenya                    KE
# 119173            11          325            Kenya                    KE
#
#        location.geo.level   location.geo.pairs location.geo.type  \
# 41588                town  -0.683333 34.766667             point
# 43731                town  -0.683333 34.766667             point
# 119173               town   0.516667 35.283333             point
#
#        location.town                name partner_id payments  \
# 41588          Kisii               Irene        133       []
# 43731          Kisii            Geoffrey        133       []
# 119173       Eldoret  Florence Ilamwenya        133       []
#
#        planned_expiration_date           posted_date          sector   status  \
# 41588     2015-07-14T00:10:02Z  2015-06-14T00:10:02Z          Retail   funded
# 43731     2015-06-14T20:10:02Z  2015-05-15T20:10:02Z  Transportation  expired
# 119173                     NaN  2010-10-12T18:20:08Z       Education   funded
#
#                                                      tags  \
# 41588   [{'name': 'user_favorite'}, {'name': '#First L...
# 43731   [{'name': '#First Loan'}, {'name': '#Parent'},...
# 119173                                                 []
#
#         terms.disbursal_amount terms.disbursal_currency  terms.disbursal_date  \
# 41588                  25000.0                      KES  2015-05-26T07:00:00Z
# 43731                  25000.0                      KES  2015-04-28T07:00:00Z
# 119173                 25000.0                      KES  2010-09-30T07:00:00Z
#
#         terms.loan_amount terms.local_payments  \
# 41588                 275                   []
# 43731                 275                   []
# 119173                325                   []
#
#        terms.loss_liability.currency_exchange  \
# 41588                                  shared
# 43731                                  shared
# 119173                                 shared
#
#         terms.loss_liability.currency_exchange_coverage_rate  \
# 41588                                                 0.1
# 43731                                                 0.1
# 119173                                                0.2
#
#        terms.loss_liability.nonpayment terms.repayment_interval  \
# 41588                           lender                      NaN
# 43731                           lender                      NaN
# 119173                          lender                      NaN
#
#         terms.repayment_term terms.scheduled_payments themes  \
# 41588                     12                       []    NaN
# 43731                     12                       []    NaN
# 119173                    11                       []    NaN
#
#        translator.byline  translator.image  \
# 41588    Nathan Tichenor           28733.0
# 43731    Lauri Fried-Lee         2210835.0
# 119173         Kent Chao          988875.0
#
#                                                       use  video.id  \
# 41588   to buy more retail products to sell in the mar...       NaN
# 43731               to service and repair his motorcycle.       NaN
# 119173               To buy more desks for the classroom.       NaN
#
#         video.thumbnailImageId video.title video.youtubeId  borrower_count  \
# 41588                      NaN         NaN             NaN               1
# 43731                      NaN         NaN             NaN               1
# 119173                     NaN         NaN             NaN               1
#
#         partner_average_loan_size_percent_per_capita_income  \
# 41588                                                34.9
# 43731                                                34.9
# 119173                                               34.9
#
#        partner_charges_fees_and_interest  \
# 41588                               True
# 43731                               True
# 119173                              True
#
#                                         partner_countries  \
# 41588   [{'iso_code': 'KE', 'region': 'Africa', 'name'...
# 43731   [{'iso_code': 'KE', 'region': 'Africa', 'name'...
# 119173  [{'iso_code': 'KE', 'region': 'Africa', 'name'...
#
#         partner_currency_exchange_loss_rate  partner_default_rate  \
# 41588                              0.089354              3.652283
# 43731                              0.089354              3.652283
# 119173                             0.089354              3.652283
#
#         partner_default_rate_note  partner_delinquency_rate  \
# 41588                         NaN                  8.017062
# 43731                         NaN                  8.017062
# 119173                        NaN                  8.017062
#
#         partner_delinquency_rate_note  partner_image.id  \
# 41588                             NaN         1495190.0
# 43731                             NaN         1495190.0
# 119173                            NaN         1495190.0
#
#         partner_image.template_id  partner_loans_at_risk_rate  \
# 41588                         1.0                   16.058249
# 43731                         1.0                   16.058249
# 119173                        1.0                   16.058249
#
#         partner_loans_posted      partner_name  partner_portfolio_yield  \
# 41588                30794.0  VisionFund Kenya                     36.0
# 43731                30794.0  VisionFund Kenya                     36.0
# 119173               30794.0  VisionFund Kenya                     36.0
#
#         partner_portfolio_yield_note  partner_profitability partner_rating  \
# 41588                            NaN                   -1.7            2.5
# 43731                            NaN                   -1.7            2.5
# 119173                           NaN                   -1.7            2.5
#
#                      partner_social_performance_strengths  \
# 41588   [{'id': 1, 'name': 'Anti-Poverty Focus', 'desc...
# 43731   [{'id': 1, 'name': 'Anti-Poverty Focus', 'desc...
# 119173  [{'id': 1, 'name': 'Anti-Poverty Focus', 'desc...
#
#           partner_start_date partner_status  partner_total_amount_raised  \
# 41588   2009-05-29T11:35:11Z         active                   11366975.0
# 43731   2009-05-29T11:35:11Z         active                   11366975.0
# 119173  2009-05-29T11:35:11Z         active                   11366975.0
#
#                               partner_url
# 41588   http://www.visionfundkenya.co.ke/
# 43731   http://www.visionfundkenya.co.ke/
# 119173  http://www.visionfundkenya.co.ke/

# %%
df.loc[df['name']=='Salome'].head(1)
# Out:
#      Unnamed: 0        activity  basket_amount  bonus_credit_eligibility  \
# 542         542  Clothing Sales            0.0                     False
#
#                                              borrowers  \
# 542  [{'first_name': 'Salome', 'last_name': '', 'ge...
#
#      currency_exchange_loss_amount description.languages  \
# 542                            NaN                ['en']
#
#                                   description.texts.en description.texts.es  \
# 542  Salome is 40 years old and married with 3 chil...                  NaN
#
#     description.texts.fr description.texts.ru  funded_amount funded_date  \
# 542                  NaN                  NaN              0         NaN
#
#           id  image.id  image.template_id  journal_totals.bulkEntries  \
# 542  1285843   2508289                  1                           0
#
#      journal_totals.entries  lender_count  loan_amount location.country  \
# 542                       0             0          200            Kenya
#
#     location.country_code location.geo.level   location.geo.pairs  \
# 542                    KE               town  -1.516667 37.266667
#
#     location.geo.type location.town    name partner_id payments  \
# 542             point      Machakos  Salome        386       []
#
#     planned_expiration_date           posted_date    sector       status  \
# 542    2017-05-31T22:40:03Z  2017-05-01T22:40:03Z  Clothing  fundraising
#
#                       tags  terms.disbursal_amount terms.disbursal_currency  \
# 542  [{'name': '#Parent'}]                 20000.0                      KES
#
#      terms.disbursal_date  terms.loan_amount  \
# 542  2017-03-29T07:00:00Z                200
#
#                                   terms.local_payments  \
# 542  [{'due_date': '2017-05-09T07:00:00Z', 'amount'...
#
#     terms.loss_liability.currency_exchange  \
# 542                                 shared
#
#      terms.loss_liability.currency_exchange_coverage_rate  \
# 542                                                0.1
#
#     terms.loss_liability.nonpayment terms.repayment_interval  \
# 542                          lender                  Monthly
#
#      terms.repayment_term                           terms.scheduled_payments  \
# 542                    15  [{'due_date': '2017-07-01T07:00:00Z', 'amount'...
#
#     themes translator.byline  translator.image  \
# 542    NaN      Ginny Maceda               NaN
#
#                                                    use  video.id  \
# 542  to buy more clothes to grow her business and s...       NaN
#
#      video.thumbnailImageId video.title video.youtubeId  borrower_count  \
# 542                     NaN         NaN             NaN               1
#
#      partner_average_loan_size_percent_per_capita_income  \
# 542                                                0.0
#
#     partner_charges_fees_and_interest  \
# 542                              True
#
#                                      partner_countries  \
# 542  [{'iso_code': 'KE', 'region': 'Africa', 'name'...
#
#      partner_currency_exchange_loss_rate  partner_default_rate  \
# 542                             0.120642                   0.0
#
#      partner_default_rate_note  partner_delinquency_rate  \
# 542                        NaN                  7.017031
#
#      partner_delinquency_rate_note  partner_image.id  \
# 542                            NaN         1592272.0
#
#      partner_image.template_id  partner_loans_at_risk_rate  \
# 542                        1.0                   21.165398
#
#      partner_loans_posted partner_name  partner_portfolio_yield  \
# 542                1948.0  Kenya ECLOF                     40.3
#
#      partner_portfolio_yield_note  partner_profitability partner_rating  \
# 542                           NaN                   2.54            2.0
#
#                   partner_social_performance_strengths    partner_start_date  \
# 542  [{'id': 3, 'name': 'Client Voice', 'descriptio...  2014-05-29T13:30:02Z
#
#     partner_status  partner_total_amount_raised                  partner_url
# 542         active                     863375.0  http://www.eclof-kenya.org/

# %% [markdown]
# A big part of exploratory analysis involves data validation. This means gaining an understanding of the distribution of data, any potential data issues that can affect the quality of your model. As we learnt during our theory lesson, " Data preparation accounts for about 80% of the work of data scientists.” [source](https://www.forbes.com/sites/gilpress/2016/03/23/data-preparation-most-time-consuming-least-enjoyable-data-science-task-survey-says/#27df67b36f63).
#
# What does data cleaning look like:
#
# 1) Are my variables the right type?
#
# Type is very important in Python programing, because it affects the types of functions you can apply to a series. There are a few different types of data you will see regularly (see [this](https://en.wikibooks.org/wiki/Python_Programming/Data_Types) link for more detail):
# * **int** - a number with no decimal places. example: loan_amount field
# * **float** - a number with decimal places. example: partner_id field
# * **str** - str is short for string. This type formally defined as a sequence of unicode characters. More simply, string means that the data is treated as a word, not a number. example: sector
# * **boolean** - can only be True or False. There is not currently an example in the data, but we will be creating a gender field shortly.
# * **datetime** - values meant to hold time data. Example: posted_date
#
# 2) Is there missing data?
#
# If we have missing data, is the missing data at random or not at random? If data is missing at random, the data distribution is still representative of the population. You can probably ignore the missing values as an inconvienience. However, if the data is missing systematically, any modeling you do may be biased. You should carefully consider the best way to clean the data, it may involve dropping some data. See [here](https://en.wikipedia.org/wiki/Missing_data) for additional information.
#
# 3) Sanity check the data, does it match what you expected to find:
# - is the range of values what you would expect. For example, are all loan_amounts above 0.
# - do you have the number of rows you would expect
# - is your data for the date range you would expect. For example, is there a strange year in the data like 1880.
# - are there unexpected spikes when you plot the data over time

# %% [markdown]
# ### Are my variables the right type?

# %% [markdown]
# Let's check the type of our variables using the examples we in the cell above.

# %%
type_example=df[['loan_amount','partner_id', 'sector','posted_date']]

# %%
type_example.sample(3)
# Out:
#        loan_amount partner_id  sector           posted_date
# 43917          125        NaN    Food  2015-05-13T06:41:32Z
# 28565          200        138  Retail  2016-01-21T13:20:06Z
# 36646          200        138    Food  2015-08-21T17:30:02Z

# %%
type_example['loan_amount'].dtype
type_example['partner_id'].dtype
type_example['sector'].dtype
type_example['posted_date'].dtype
# Out:
# dtype('int64')
# dtype('O')
# dtype('O')
# dtype('O')

# %% [markdown]
# Immediately, we notice we have an issue. Type 'O' means object which in the pandas world means a string. This makes sense for the sector field but not for the posted_date field. We want pandas to treat this field as a datetime field, we will have to tell pandas to convert it. This is annoying but important because we will be ploting time series charts. We need python to recognize posted_date as a date in order to apply some of the operations necessary.

# %% [markdown]
# We use the panda function `to_datetime`, which converts our format from object to datetime. You can run the `.dtype` command above to verify we have converted successfully. We also want to create a YY-MM variable for each, which will allow us to more easily aggregate our data later in the module.

# %%
df['posted_datetime'] = pd.to_datetime(df['posted_date'])
df['planned_expiration_datetime'] = pd.to_datetime(df['planned_expiration_date'])
df['funded_datetime'] = pd.to_datetime(df['funded_date'])
df['dispursal_datetime'] = pd.to_datetime(df['terms.disbursal_date'])
df['number_of_loans']=1

# %%
df['posted_date']=df['posted_datetime'].dt.date
df['planned_expiration_date']=df['planned_expiration_datetime'].dt.date
df['funded_date']=df['funded_datetime'].dt.date
df['dispersal_date']=df['dispursal_datetime'].dt.date
df['posted_year']=df['posted_datetime'].dt.year

# %% [markdown]
# We can check if we were successful by checking the type again. We were successful!

# %%
df['posted_datetime'].head(1)
df['posted_datetime'].dtype
# Out:
# 0   2017-05-09 00:40:03
# Name: posted_datetime, dtype: datetime64[ns]
# dtype('<M8[ns]')

# %% [markdown]
# Now that we have successfully manipulated our data fields we can plot the time range of our data. This is an important piece of sanity checking because if we see an unexpected year, or big spikes in one year we should be suspicious about the quality of our data.

# %%
ts=df[['posted_datetime','number_of_loans']]
ts = ts.set_index(['posted_datetime'])
ts=ts.groupby(ts.index.year).sum()
ts['Date'] = ts.index
ts.reset_index(drop=True)

ggplot(ts , aes(x = 'Date', y = 'number_of_loans')) + geom_point(color = "blue") + \
ggtitle("Number of Kenyan Loans on Kiva each year") + xlab("Date") + ylab("Number of Loans")
# Out:
#     number_of_loans  Date
# 0               511  2006
# 1              2143  2007
# 2               384  2008
# 3              1730  2009
# 4              6050  2010
# 5             13182  2011
# 6             16054  2012
# 7             16228  2013
# 8             19222  2014
# 9             22594  2015
# 10            20630  2016
# 11             9230  2017
# <ggplot: (34050078917)>

# %% [markdown]
# In the chart above we can see that we have loan data from 2006 through to 2017. This seems reasonable and means KIVA has been lending in Kenya for 11 years. We also see that although the number of loans has grown each year there is a dip in 2017. However, this isn't that suspicious because remember that we are only in May, so the total volume will likely increase by December.

# %%
ts=df[['posted_datetime','loan_amount']]
ts = ts.set_index(['posted_datetime'])
ts=ts.groupby(ts.index.year).sum()
ts['Date'] = ts.index
ts.reset_index(drop=True)

ggplot(ts , aes(x = 'Date', y = 'loan_amount')) + geom_point(color = "blue") + \
ggtitle("Volume of loan amount on Kiva each year") + xlab("Date") + ylab("Sum of loan amount")
# Out:
#     loan_amount  Date
# 0        274975  2006
# 1       1172000  2007
# 2        364500  2008
# 3        788150  2009
# 4       2985625  2010
# 5       5788500  2011
# 6       7163925  2012
# 7       8973675  2013
# 8       9196175  2014
# 9       9638775  2015
# 10      9978550  2016
# 11      4107050  2017
# <ggplot: (-9223372002804712220)>

# %% [markdown]
# We see a similar patten in the sum of dollars loaned. It mimics the distribution of the number of loans which is a good sign.

# %% [markdown]
# ### Do I have missing values?

# %% [markdown]
# Remember when we used a left join to merge in the partner data. That means we could have null (missing) values in our partner_id field. We check this in the cell below and find that we have 9,642 loans that are missing. Let's investigate and try and understand whether the data is missing at random or systematically missing.

# %%
len(df.index)-df['partner_id'].count()
# Out:
# 9642

# %%
null_partner_id=df.loc[df['partner_id'].isnull()]

# %%
len(null_partner_id.index)
# Out:
# 9642

# %%
null_partner_id.head(2)
# Out:
#        Unnamed: 0     activity  basket_amount  bonus_credit_eligibility  \
# 36064       36048       Health            NaN                     False
# 36068       36052  Agriculture            NaN                     False
#
#                                                borrowers  \
# 36064  [{'first_name': 'Doroffine', 'last_name': '', ...
# 36068  [{'first_name': 'Brenda Bugutsa', 'last_name':...
#
#        currency_exchange_loss_amount description.languages  \
# 36064                           0.01                ['en']
# 36068                           0.01                ['en']
#
#                                     description.texts.en description.texts.es  \
# 36064  I grew up in Kitui county, was faced with many...                  NaN
# 36068  I grew up in Vihiga county Western Kenya in a ...                  NaN
#
#       description.texts.fr description.texts.ru  funded_amount funded_date  \
# 36064                  NaN                  NaN            225  2015-09-04
# 36068                  NaN                  NaN            225  2015-09-03
#
#             id  image.id  image.template_id  journal_totals.bulkEntries  \
# 36064  1090127   2208140                  1                           0
# 36068  1090116   2208117                  1                           0
#
#        journal_totals.entries  lender_count  loan_amount location.country  \
# 36064                       0             6          225            Kenya
# 36068                       0             6          225            Kenya
#
#       location.country_code location.geo.level location.geo.pairs  \
# 36064                    KE            country               1 38
# 36068                    KE            country               1 38
#
#       location.geo.type location.town            name partner_id payments  \
# 36064             point           NaN       Doroffine        NaN       []
# 36068             point           NaN  Brenda Bugutsa        NaN       []
#
#       planned_expiration_date posted_date       sector  status tags  \
# 36064              2015-10-17  2015-09-02       Health  funded   []
# 36068              2015-10-17  2015-09-02  Agriculture  funded   []
#
#        terms.disbursal_amount terms.disbursal_currency  terms.disbursal_date  \
# 36064                 20000.0                      KES  2015-09-14T11:07:00Z
# 36068                 20000.0                      KES  2015-09-10T16:23:00Z
#
#        terms.loan_amount terms.local_payments  \
# 36064                225                   []
# 36068                225                   []
#
#       terms.loss_liability.currency_exchange     ...      \
# 36064                                partner     ...
# 36068                                partner     ...
#
#        terms.repayment_term terms.scheduled_payments themes  \
# 36064                     6                       []    NaN
# 36068                     6                       []    NaN
#
#        translator.byline translator.image  \
# 36064                NaN              NaN
# 36068                NaN              NaN
#
#                                                      use video.id  \
# 36064  buy medicines, stethoscope, glucometer and exa...      NaN
# 36068  purchase more cereals stocks  and charcoal sto...      NaN
#
#        video.thumbnailImageId video.title  video.youtubeId  borrower_count  \
# 36064                     NaN         NaN              NaN               1
# 36068                     NaN         NaN              NaN               1
#
#       partner_average_loan_size_percent_per_capita_income  \
# 36064                                                NaN
# 36068                                                NaN
#
#       partner_charges_fees_and_interest  partner_countries  \
# 36064                               NaN                NaN
# 36068                               NaN                NaN
#
#        partner_currency_exchange_loss_rate partner_default_rate  \
# 36064                                  NaN                  NaN
# 36068                                  NaN                  NaN
#
#       partner_default_rate_note  partner_delinquency_rate  \
# 36064                       NaN                       NaN
# 36068                       NaN                       NaN
#
#        partner_delinquency_rate_note  partner_image.id  \
# 36064                            NaN               NaN
# 36068                            NaN               NaN
#
#        partner_image.template_id  partner_loans_at_risk_rate  \
# 36064                        NaN                         NaN
# 36068                        NaN                         NaN
#
#        partner_loans_posted  partner_name  partner_portfolio_yield  \
# 36064                   NaN           NaN                      NaN
# 36068                   NaN           NaN                      NaN
#
#        partner_portfolio_yield_note partner_profitability  partner_rating  \
# 36064                           NaN                   NaN             NaN
# 36068                           NaN                   NaN             NaN
#
#        partner_social_performance_strengths  partner_start_date  \
# 36064                                   NaN                 NaN
# 36068                                   NaN                 NaN
#
#       partner_status partner_total_amount_raised partner_url  \
# 36064            NaN                         NaN         NaN
# 36068            NaN                         NaN         NaN
#
#           posted_datetime  planned_expiration_datetime     funded_datetime  \
# 36064 2015-09-02 17:52:12          2015-10-17 10:52:11 2015-09-04 02:44:28
# 36068 2015-09-02 17:44:11          2015-10-17 10:44:09 2015-09-03 15:10:11
#
#        dispursal_datetime number_of_loans dispersal_date posted_year
# 36064 2015-09-14 11:07:00               1     2015-09-14        2015
# 36068 2015-09-10 16:23:00               1     2015-09-10        2015
#
# [2 rows x 83 columns]

# %%
ts=null_partner_id[['posted_datetime','number_of_loans']]
ts = ts.set_index(['posted_datetime'])
ts=ts.groupby(ts.index.year).sum()
ts['Date'] = ts.index
ts.reset_index(drop=True)

ggplot(ts , aes(x = 'Date', y = 'number_of_loans')) + geom_point(color = "blue") + \
ggtitle("Number of Kenyan Loans on Kiva each year") + xlab("Date") + ylab("Number of Loans")
# Out:
#    number_of_loans  Date
# 0               16  2011
# 1              359  2012
# 2             1077  2013
# 3             4725  2014
# 4             3465  2015
# <ggplot: (-9223372002897455591)>

# %% [markdown]
# It seems that the number of loans peaked in 2014, and has decreased. All of the loans issued in the second half of 2015, 2016, 2017 have a partner. This tells us these values are not missing at random, they are more likely to occur in data before June 2015, and are most likely to occur in the first half of 2014. We should probably just drop data with the partner_id missing. We do so below using the notnull() function which checks if the field is populated.

# %%
df=df.loc[df['partner_id'].notnull()]

# %% [markdown]
# As a sanity check that our filtering was correctly done we check the new number of rows. It makes sense!

# %%
len(df.index)
# Out:
# 118316

# %% [markdown]
# ### Additional Sanity Checks

# %% [markdown]
# **Does the dataset have the number of rows you would expect?**
#
# In the command below we find out the number of loans and number of columns by using the function shape. You can also use len(df.index) to find the number of rows.

# %%
print('There are %d observations and %d features' % (df.shape[0],df.shape[1]))
# Out:
# There are 118316 observations and 83 features

# %% [markdown]
# This tells us there are 127,958 observations and 84 features. We learnt in the theory lesson that each row is an observation and each column is a potential feature. 127,000 matches with what we expect based upon our conversations with Kiva. This is a very healthy sample size for applying machine learning algorithms.
#
# NB: My values are differing from those obtained by the facilitators. Not sure why this is so.

# %% [markdown]
# ### Descriptive statistics of the dataset

# %% [markdown]
# In the theory part of the lesson, we learnt about mean, frequency and percentiles as a powerful way to understand the distribution of the data. If you are unfamiliar with these terms or need a refresher [this](https://www.mathsisfun.com/data/frequency-grouped-mean-median-mode.html) overview should be helpful.The describe command below provides key summary statistics for each numeric column.

# %%
print(df.describe())
# Out:
#           Unnamed: 0  basket_amount  currency_exchange_loss_amount  \
# count  118316.000000     944.000000                   15690.000000
# mean    64398.230239       0.185381                       7.017447
# std     38157.158427       2.145937                      15.655207
# min         0.000000       0.000000                       0.010000
# 25%     29564.750000       0.000000                       1.220000
# 50%     66517.500000       0.000000                       3.490000
# 75%     98238.250000       0.000000                       8.280000
# max    127899.000000      25.000000                    1285.510000
#
#        funded_amount            id      image.id  image.template_id  \
# count  118316.000000  1.183160e+05  1.183160e+05           118316.0
# mean      473.439771  7.096035e+05  1.540915e+06                1.0
# std       676.663803  3.412929e+05  6.043467e+05                0.0
# min         0.000000  2.510000e+02  4.090000e+02                1.0
# 25%       250.000000  4.202852e+05  1.013473e+06                1.0
# 50%       350.000000  6.975760e+05  1.575774e+06                1.0
# 75%       600.000000  1.003961e+06  2.052755e+06                1.0
# max     50000.000000  1.292273e+06  2.516905e+06                1.0
#
#        journal_totals.bulkEntries  journal_totals.entries   lender_count  \
# count                    118316.0                118316.0  118316.000000
# mean                          0.0                     0.0      14.608227
# std                           0.0                     0.0      20.216517
# min                           0.0                     0.0       0.000000
# 25%                           0.0                     0.0       7.000000
# 50%                           0.0                     0.0      11.000000
# 75%                           0.0                     0.0      18.000000
# max                           0.0                     0.0    1589.000000
#
#          loan_amount  terms.disbursal_amount  terms.loan_amount  \
# count  118316.000000            1.183160e+05      118316.000000
# mean      495.159784            4.178579e+04         495.159784
# std       704.079168            4.474124e+04         704.079168
# min        25.000000            2.500000e+01          25.000000
# 25%       250.000000            2.000000e+04         250.000000
# 50%       375.000000            3.000000e+04         375.000000
# 75%       600.000000            5.000000e+04         600.000000
# max     50000.000000            1.596948e+06       50000.000000
#
#        terms.loss_liability.currency_exchange_coverage_rate  \
# count                                      114447.000000
# mean                                            0.122154
# std                                             0.041529
# min                                             0.100000
# 25%                                             0.100000
# 50%                                             0.100000
# 75%                                             0.100000
# max                                             0.200000
#
#        terms.repayment_term  translator.image     video.id  \
# count         118316.000000      6.301700e+04    76.000000
# mean              13.461079      1.165835e+06  1291.697368
# std                8.147379      7.036716e+05  1027.999559
# min                2.000000      2.392400e+04   150.000000
# 25%               11.000000      5.186710e+05   487.750000
# 50%               14.000000      1.186147e+06   665.500000
# 75%               14.000000      1.668411e+06  2154.250000
# max              122.000000      2.499150e+06  3008.000000
#
#        video.thumbnailImageId  borrower_count  \
# count            7.600000e+01   118316.000000
# mean             6.155305e+05        1.930686
# std              4.622450e+05        3.031490
# min              2.975740e+05        1.000000
# 25%              3.244948e+05        1.000000
# 50%              3.361080e+05        1.000000
# 75%              6.247900e+05        1.000000
# max              1.754457e+06       46.000000
#
#        partner_average_loan_size_percent_per_capita_income  \
# count                                      118316.000000
# mean                                           30.026747
# std                                            17.099929
# min                                             0.000000
# 25%                                            24.300000
# 50%                                            34.900000
# 75%                                            40.100000
# max                                            54.800000
#
#        partner_currency_exchange_loss_rate  partner_default_rate  \
# count                        118316.000000         118316.000000
# mean                              0.212524              3.821426
# std                               0.262458             10.477770
# min                               0.000000              0.000000
# 25%                               0.089354              0.085473
# 50%                               0.164711              1.483890
# 75%                               0.364948              3.652283
# max                               7.513861             94.939083
#
#        partner_default_rate_note  partner_delinquency_rate  \
# count                        0.0             118316.000000
# mean                         NaN                  4.358150
# std                          NaN                  5.472373
# min                          NaN                  0.000000
# 25%                          NaN                  0.000000
# 50%                          NaN                  2.536684
# 75%                          NaN                  8.017062
# max                          NaN                100.000000
#
#        partner_delinquency_rate_note  partner_image.id  \
# count                            0.0      1.183160e+05
# mean                             NaN      1.496709e+06
# std                              NaN      6.022014e+05
# min                              NaN      3.560000e+02
# 25%                              NaN      1.495190e+06
# 50%                              NaN      1.592689e+06
# 75%                              NaN      2.081410e+06
# max                              NaN      2.520600e+06
#
#        partner_image.template_id  partner_loans_at_risk_rate  \
# count                   118316.0               118316.000000
# mean                         1.0                   11.528738
# std                          0.0                   10.893620
# min                          1.0                    0.000000
# 25%                          1.0                    0.000000
# 50%                          1.0                   16.058249
# 75%                          1.0                   18.498507
# max                          1.0                  100.000000
#
#        partner_loans_posted  partner_portfolio_yield  \
# count         118316.000000            111917.000000
# mean           18174.752434                31.054133
# std             9423.900289                10.444965
# min                0.000000                 0.000000
# 25%             9546.000000                29.000000
# 50%            18150.000000                33.100000
# 75%            21415.000000                36.000000
# max            30794.000000                41.000000
#
#        partner_portfolio_yield_note  partner_profitability  \
# count                           0.0          106890.000000
# mean                            NaN               2.362943
# std                             NaN              11.299052
# min                             NaN            -117.790000
# 25%                             NaN              -1.700000
# 50%                             NaN               0.000000
# 75%                             NaN               2.230000
# max                             NaN              30.300000
#
#        partner_total_amount_raised  number_of_loans    posted_year
# count                 1.183160e+05         118316.0  118316.000000
# mean                  7.309958e+06              1.0    2013.558783
# std                   3.289116e+06              0.0       2.343340
# min                   0.000000e+00              1.0    2006.000000
# 25%                   6.764500e+06              1.0    2012.000000
# 50%                   7.646925e+06              1.0    2014.000000
# 75%                   8.133425e+06              1.0    2016.000000
# max                   1.136698e+07              1.0    2017.000000

# %% [markdown]
# In order to get the same summary statistics for categorical columns (string) we need to do a little data wrangling. The first line of code filters for all columns that are a data type object. As we know from before this means they are considered to be a string. The final row of code provides summary statistics for these character fields.

# %%
categorical = df.dtypes[df.dtypes == "object"].index
df[categorical].head(1)
df[categorical].describe()
# Out:
#   activity                                          borrowers  \
# 0  Farming  [{'first_name': 'Evaline', 'last_name': '', 'g...
#
#   description.languages                               description.texts.en  \
# 0                ['en']  Evaline is a married lady aged 44 years old an...
#
#   description.texts.es description.texts.fr description.texts.ru funded_date  \
# 0                  NaN                  NaN                  NaN         NaN
#
#   location.country location.country_code location.geo.level  \
# 0            Kenya                    KE               town
#
#     location.geo.pairs location.geo.type location.town     name partner_id  \
# 0  -0.583333 35.183333             point        litein  Evaline        386
#
#   payments planned_expiration_date posted_date       sector       status  \
# 0       []              2017-06-08  2017-05-09  Agriculture  fundraising
#
#                                                 tags terms.disbursal_currency  \
# 0  [{'name': '#Woman Owned Biz'}, {'name': '#Pare...                      KES
#
#    terms.disbursal_date                               terms.local_payments  \
# 0  2017-04-03T07:00:00Z  [{'due_date': '2017-05-10T07:00:00Z', 'amount'...
#
#   terms.loss_liability.currency_exchange terms.loss_liability.nonpayment  \
# 0                                 shared                          lender
#
#   terms.repayment_interval                           terms.scheduled_payments  \
# 0                  Monthly  [{'due_date': '2017-07-01T07:00:00Z', 'amount'...
#
#   themes translator.byline                                                use  \
# 0    NaN      Julie Keaton  to purchase more tea leaves to sell to the tea...
#
#   video.title video.youtubeId partner_charges_fees_and_interest  \
# 0         NaN             NaN                              True
#
#                                    partner_countries partner_name  \
# 0  [{'iso_code': 'KE', 'region': 'Africa', 'name'...  Kenya ECLOF
#
#   partner_rating               partner_social_performance_strengths  \
# 0            2.0  [{'id': 3, 'name': 'Client Voice', 'descriptio...
#
#      partner_start_date partner_status                  partner_url  \
# 0  2014-05-29T13:30:02Z         active  http://www.eclof-kenya.org/
#
#   dispersal_date
# 0     2017-04-03
#        activity                                          borrowers  \
# count    118316                                             118316
# unique      149                                              29987
# top     Farming  [{'first_name': 'Anonymous', 'last_name': '', ...
# freq      26243                                               2420
#
#        description.languages  \
# count                 118316
# unique                     4
# top                   ['en']
# freq                  118306
#
#                                      description.texts.en  \
# count                                              113988
# unique                                             113859
# top     Hello Kiva Community! <br /><br />Meet Jane, w...
# freq                                                    5
#
#                                      description.texts.es  \
# count                                                   3
# unique                                                  3
# top     The person appearing in the photo is Agnes. Sh...
# freq                                                    1
#
#                                      description.texts.fr  \
# count                                                   3
# unique                                                  3
# top     Mwanajuma is a married woman with two children...
# freq                                                    1
#
#                                      description.texts.ru funded_date  \
# count                                                   4      112704
# unique                                                  4        3452
# top     Joyce is a married woman. She has 6 children. ...  2016-03-08
# freq                                                    1         413
#
#        location.country location.country_code location.geo.level  \
# count            118316                118316             118316
# unique                1                     1                  2
# top               Kenya                    KE               town
# freq             118316                118316             110407
#
#        location.geo.pairs location.geo.type location.town       name  \
# count              118316            118316        110407     118316
# unique                 47                 1          1249      16047
# top                  1 38             point        Likoni  Anonymous
# freq                77254            118316          5035       3680
#
#         partner_id payments planned_expiration_date posted_date       sector  \
# count     118316.0   118316                   93403      118316       118316
# unique        52.0        1                    1860        3174           15
# top          133.0       []              2014-03-26  2014-02-24  Agriculture
# freq       28570.0   118316                     621         621        45638
#
#         status    tags terms.disbursal_currency  terms.disbursal_date  \
# count   118316  118316                   118316                118316
# unique       3    5426                        2                  5413
# top     funded      []                      KES  2017-02-01T08:00:00Z
# freq    112704   65318                   115076                  2498
#
#        terms.local_payments terms.loss_liability.currency_exchange  \
# count                118316                                 118316
# unique                  736                                      3
# top                      []                                 shared
# freq                 117372                                 113783
#
#        terms.loss_liability.nonpayment terms.repayment_interval  \
# count                           118316                      944
# unique                               2                        3
# top                             lender                  Monthly
# freq                            115735                      622
#
#        terms.scheduled_payments               themes translator.byline  \
# count                    118316                29014             82362
# unique                      277                   27               425
# top                          []  ['Rural Exclusion']        Tim Gibson
# freq                     117372                15663              6917
#
#                                                       use  \
# count                                              113989
# unique                                              58864
# top     to purchase a solar light and gain access to c...
# freq                                                 1405
#
#                            video.title video.youtubeId  \
# count                               76              76
# unique                              72              74
# top     Kiva Borrower PETRE from Kenya     6dWFtYShzBk
# freq                                 2               2
#
#        partner_charges_fees_and_interest  \
# count                             118316
# unique                                 2
# top                                 True
# freq                              117376
#
#                                         partner_countries      partner_name  \
# count                                              118316            118316
# unique                                                 11                52
# top     [{'iso_code': 'KE', 'region': 'Africa', 'name'...  VisionFund Kenya
# freq                                               106639             28570
#
#        partner_rating               partner_social_performance_strengths  \
# count          118316                                             113754
# unique              9                                                 16
# top               3.5  [{'id': 1, 'name': 'Anti-Poverty Focus', 'desc...
# freq            39681                                              46681
#
#           partner_start_date partner_status  \
# count                 118316         118316
# unique                    52              3
# top     2009-05-29T11:35:11Z         active
# freq                   28570         104271
#
#                               partner_url dispersal_date
# count                              114249         118316
# unique                                 34           3081
# top     http://www.visionfundkenya.co.ke/     2017-02-01
# freq                                28570           2498

# %% [markdown]
# ## Step 3: Exploratory Analysis

# %% [markdown]
# ## Step 3 a: What sectors get the most funding?

# %% [markdown]
# The pie chart below shows that agriculuture and food have the most loans in Kenya.

# %%
df['sector'].value_counts().plot(kind='pie',title='Outliers by Sector')

# %% [markdown]
# What is the average loan amount for each sector? We see that Agriculture has the largest average loan value.

# %%
df.groupby('sector')['loan_amount'].mean()
# Out:
# sector
# Agriculture        563.734169
# Arts               406.397638
# Clothing           429.577926
# Construction       439.261651
# Education          876.895799
# Entertainment      476.286765
# Food               379.565182
# Health            1031.538797
# Housing            512.875000
# Manufacturing      546.231721
# Personal Use       242.357294
# Retail             490.601514
# Services           452.595146
# Transportation     514.767473
# Wholesale          590.485075
# Name: loan_amount, dtype: float64

# %% [markdown]
# We can also visualize this as a bar chart.

# %%
df.groupby('sector')['loan_amount'].mean().plot(kind="bar")

# %% [markdown]
# Below, we change out metric of interest to the total sum of dollars invested. Agriculture still comes out on top.

# %%
df.groupby('sector')['loan_amount'].sum().plot(kind="bar")

# %% [markdown]
# We can also look at the distribution of loans by sector.

# %%
print("There are %d different activities" % df.activity.value_counts().size)
print("\n Just looking at the top 15 activites")
df.activity.value_counts()[0:16].plot(kind='bar',figsize=(12,3))
# Out:
# There are 149 different activities
#
#  Just looking at the top 15 activites

# %% [markdown]
# Since we know agriculture loans tend to be larger on average, it would be interesting to see if they tend to have more borrowers.

# %%
print(df.groupby("borrower_count").size());
ggplot(df[df['borrower_count'] < 20], aes(x='borrower_count', fill='sector')) +\
    geom_histogram(binwidth=1)
# Out:
# borrower_count
# 1     105297
# 2        847
# 3        656
# 4        587
# 5        762
# 6        622
# 7        724
# 8       1044
# 9       1004
# 10      1432
# 11      1124
# 12      1096
# 13       855
# 14       754
# 15       615
# 16       475
# 17        51
# 18        32
# 19        71
# 20       135
# 21        34
# 22        17
# 23        15
# 24        20
# 25        15
# 26         8
# 27         2
# 28         3
# 29         1
# 30         2
# 31         3
# 32         3
# 33         2
# 34         1
# 37         1
# 39         1
# 40         1
# 41         1
# 42         1
# 45         1
# 46         1
# dtype: int64
# <ggplot: (34054309110)>

# %% [markdown]
# We see that the bulk of all loans only have a single borrower, but agriculture loans tends to be outliers and much more likely to have multiple borrowers.

# %% [markdown]
# ## Step 3 b: What amount do people lend on average?

# %% [markdown]
# The chart below shows a strong relationship between loan amount and number of lenders. This suggests to us that as the loan amount goes up the amount donated by any lender does not. Instead larger loans are simply fulfiled by more individual lenders. This makes sense given our understanding of KIVAs platform, since the majority of lenders loan the minimum $25.00.

# %%
ggplot(df , aes(x = 'loan_amount', y = 'lender_count', color='sector')) + geom_point() + \
ggtitle("Relationship between loan amount and number of lenders") + xlab("Loan Amount") + ylab("Number of lenders")
# Out:
# <ggplot: (-9223372002896147126)>

# %% [markdown]
# That might suggest that larger loans are more difficult to fulfill, since they tend on average to require more lenders. Let's take a look. We start by plotting all loans. We can already see below that the chart is skewed by outliers.

# %%
ggplot(loans_full, aes(x='loan_amount', y = 'borrower_count', color='status')) + \
    geom_point() 
##Hugely skewed by a few big loans
# Out:
# <ggplot: (34054471709)>

# %% [markdown]
# We limit our data set to all loans below $5000.00.

# %%
ggplot(df.query("loan_amount < 5000"), aes(x='loan_amount', y = 'borrower_count', color='status')) + \
    geom_point() 
    
## Expired loans tend to be bigger loans with fewer borrowers
# Out:
# <ggplot: (2932109287677)>

# %% [markdown]
# In this chart it becomes clear that a loan is more likely to expire when it is a higher loan amount.

# %% [markdown]
# ## Further practice

# %% [markdown]
# We have suggested some topics below for exploratory analysis. Try and attempt at least one topic before next class. We will share our own research at the next class, but feel free to share visualizations or interesting observations in slack.

# %% [markdown]
# ## Step 3 b: Who are the biggest lending partners?
#
# Based purely on the number of loans disbursed by a lender, we can determine that Vision Fun kenya is the biggest lending partner. However, we may need to determine the value of the loans for a better picture.

# %%
df['partner_name'].value_counts().plot(kind='bar',title='Number of loans by Lending partner',figsize=(12,3))
# Out:
# /home/ckibet/lustre/miniconda2/envs/moringa/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
df.groupby('partner_name')['loan_amount'].sum().sort_values(ascending=False).plot(kind="bar", title='Number of loans by Lending partner', figsize=(12,3))
# Out:
# /home/ckibet/lustre/miniconda2/envs/moringa/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Step 3 c: How many loans do not get funded? What are some qualities of loans that expire?

# %%
df.
# Out:
#         Unnamed: 0               activity  basket_amount  \
# 25766        25752                Farming            NaN
# 126589      126531             Shoe Sales            NaN
# 126595      126537  Food Production/Sales            NaN
# 127262      127204  Food Production/Sales            NaN
# 127263      127205                 Bakery            NaN
#
#         bonus_credit_eligibility  \
# 25766                      False
# 126589                     False
# 126595                     False
# 127262                     False
# 127263                     False
#
#                                                 borrowers  \
# 25766   [{'first_name': 'Miriam', 'last_name': '', 'ge...
# 126589  [{'first_name': 'Godfrey', 'last_name': '', 'g...
# 126595  [{'first_name': 'Wilbad', 'last_name': '', 'ge...
# 127262  [{'first_name': 'Grace', 'last_name': '', 'gen...
# 127263  [{'first_name': 'Moses', 'last_name': '', 'gen...
#
#         currency_exchange_loss_amount description.languages  \
# 25766                             NaN                ['en']
# 126589                            NaN                ['en']
# 126595                            NaN                ['en']
# 127262                            NaN                ['en']
# 127263                            NaN                ['en']
#
#                                      description.texts.en  \
# 25766   Miriam is 54 years old. She is married with 7 ...
# 126589  I am a 32-year-old married man with 3 children...
# 126595  I am a single man. I am head of a 6 family hou...
# 127262  I sell small food stuffs like beans, rice, and...
# 127263  I am a retailer of bakery products in Kisumu T...
#
#        description.texts.es description.texts.fr description.texts.ru  \
# 25766                   NaN                  NaN                  NaN
# 126589                  NaN                  NaN                  NaN
# 126595                  NaN                  NaN                  NaN
# 127262                  NaN                  NaN                  NaN
# 127263                  NaN                  NaN                  NaN
#
#         funded_amount funded_date       id  image.id  image.template_id  \
# 25766              25  2016-03-07  1033002   2112406                  1
# 126589             25  2007-04-10     5778     18064                  1
# 126595             25  2007-04-10     5953     18334                  1
# 127262             25  2007-02-02     3984     12560                  1
# 127263             25  2007-02-02     3983     12559                  1
#
#         journal_totals.bulkEntries  journal_totals.entries  lender_count  \
# 25766                            0                       0             1
# 126589                           0                       0             1
# 126595                           0                       0             1
# 127262                           0                       0             1
# 127263                           0                       0             1
#
#         loan_amount location.country location.country_code location.geo.level  \
# 25766            25            Kenya                    KE               town
# 126589           25            Kenya                    KE               town
# 126595           25            Kenya                    KE               town
# 127262           25            Kenya                    KE               town
# 127263           25            Kenya                    KE               town
#
#        location.geo.pairs location.geo.type location.town     name partner_id  \
# 25766                1 38             point      KABARNET   Miriam        133
# 126589         -0.1 34.75             point        Kisumu  Godfrey         32
# 126595         -0.1 34.75             point        Kisumu   Wilbad         32
# 127262         -0.1 34.75             point        Kisumu    Grace         32
# 127263         -0.1 34.75             point        Kisumu    Moses         32
#
#        payments planned_expiration_date posted_date       sector  status  \
# 25766        []              2016-04-06  2016-03-07  Agriculture  funded
# 126589       []                     NaN  2007-04-10       Retail  funded
# 126595       []                     NaN  2007-04-10         Food  funded
# 127262       []                     NaN  2007-02-02         Food  funded
# 127263       []                     NaN  2007-02-02         Food  funded
#
#                           tags  terms.disbursal_amount  \
# 25766   [{'name': '#Elderly'}]                  2500.0
# 126589                      []                    25.0
# 126595                      []                    25.0
# 127262                      []                    25.0
# 127263                      []                    25.0
#
#        terms.disbursal_currency  terms.disbursal_date  terms.loan_amount  \
# 25766                       KES  2016-02-03T08:00:00Z                 25
# 126589                      USD  2007-04-24T17:24:51Z                 25
# 126595                      USD  2007-04-24T16:52:42Z                 25
# 127262                      USD  2007-02-16T10:15:54Z                 25
# 127263                      USD  2007-02-16T10:15:53Z                 25
#
#        terms.local_payments terms.loss_liability.currency_exchange  \
# 25766                    []                                 shared
# 126589                   []                                   none
# 126595                   []                                   none
# 127262                   []                                   none
# 127263                   []                                   none
#
#            ...      terms.repayment_term terms.scheduled_payments themes  \
# 25766      ...                        14                       []    NaN
# 126589     ...                         3                       []    NaN
# 126595     ...                         8                       []    NaN
# 127262     ...                        10                       []    NaN
# 127263     ...                        11                       []    NaN
#
#         translator.byline translator.image  \
# 25766          Tim Gibson        1632475.0
# 126589                NaN              NaN
# 126595                NaN              NaN
# 127262                NaN              NaN
# 127263                NaN              NaN
#
#                                                       use video.id  \
# 25766                    to buy fertilizers for her farm.      NaN
# 126589          Diversify my business to include clothes.      NaN
# 126595  I intend to expand and diversify business to i...      NaN
# 127262  I will purchase an annual license and broaden ...      NaN
# 127263  To purchase a microwave to heat bakery product...      NaN
#
#         video.thumbnailImageId video.title  video.youtubeId  borrower_count  \
# 25766                      NaN         NaN              NaN               1
# 126589                     NaN         NaN              NaN               1
# 126595                     NaN         NaN              NaN               1
# 127262                     NaN         NaN              NaN               1
# 127263                     NaN         NaN              NaN               1
#
#        partner_average_loan_size_percent_per_capita_income  \
# 25766                                                34.9
# 126589                                                0.0
# 126595                                                0.0
# 127262                                                0.0
# 127263                                                0.0
#
#        partner_charges_fees_and_interest  \
# 25766                               True
# 126589                              True
# 126595                              True
# 127262                              True
# 127263                              True
#
#                                         partner_countries  \
# 25766   [{'iso_code': 'KE', 'region': 'Africa', 'name'...
# 126589  [{'iso_code': 'KE', 'region': 'Africa', 'name'...
# 126595  [{'iso_code': 'KE', 'region': 'Africa', 'name'...
# 127262  [{'iso_code': 'KE', 'region': 'Africa', 'name'...
# 127263  [{'iso_code': 'KE', 'region': 'Africa', 'name'...
#
#         partner_currency_exchange_loss_rate partner_default_rate  \
# 25766                              0.089354             3.652283
# 126589                             0.000000            18.731911
# 126595                             0.000000            18.731911
# 127262                             0.000000            18.731911
# 127263                             0.000000            18.731911
#
#        partner_default_rate_note  partner_delinquency_rate  \
# 25766                        NaN                  8.017062
# 126589                       NaN                  0.000000
# 126595                       NaN                  0.000000
# 127262                       NaN                  0.000000
# 127263                       NaN                  0.000000
#
#         partner_delinquency_rate_note  partner_image.id  \
# 25766                             NaN         1495190.0
# 126589                            NaN            7817.0
# 126595                            NaN            7817.0
# 127262                            NaN            7817.0
# 127263                            NaN            7817.0
#
#         partner_image.template_id  partner_loans_at_risk_rate  \
# 25766                         1.0                   16.058249
# 126589                        1.0                    0.000000
# 126595                        1.0                    0.000000
# 127262                        1.0                    0.000000
# 127263                        1.0                    0.000000
#
#         partner_loans_posted  \
# 25766                30794.0
# 126589                 446.0
# 126595                 446.0
# 127262                 446.0
# 127263                 446.0
#
#                                              partner_name  \
# 25766                                    VisionFund Kenya
# 126589  Supporting Enterprises for Economic Developmen...
# 126595  Supporting Enterprises for Economic Developmen...
# 127262  Supporting Enterprises for Economic Developmen...
# 127263  Supporting Enterprises for Economic Developmen...
#
#         partner_portfolio_yield  partner_portfolio_yield_note  \
# 25766                      36.0                           NaN
# 126589                      NaN                           NaN
# 126595                      NaN                           NaN
# 127262                      NaN                           NaN
# 127263                      NaN                           NaN
#
#        partner_profitability  partner_rating  \
# 25766                   -1.7             2.5
# 126589                   NaN             0.0
# 126595                   NaN             0.0
# 127262                   NaN             0.0
# 127263                   NaN             0.0
#
#                      partner_social_performance_strengths  \
# 25766   [{'id': 1, 'name': 'Anti-Poverty Focus', 'desc...
# 126589                                                NaN
# 126595                                                NaN
# 127262                                                NaN
# 127263                                                NaN
#
#           partner_start_date partner_status partner_total_amount_raised  \
# 25766   2009-05-29T11:35:11Z         active                  11366975.0
# 126589  2007-01-31T16:18:45Z         closed                     74550.0
# 126595  2007-01-31T16:18:45Z         closed                     74550.0
# 127262  2007-01-31T16:18:45Z         closed                     74550.0
# 127263  2007-01-31T16:18:45Z         closed                     74550.0
#
#                               partner_url     posted_datetime  \
# 25766   http://www.visionfundkenya.co.ke/ 2016-03-07 03:30:07
# 126589                                NaN 2007-04-10 16:54:50
# 126595                                NaN 2007-04-10 16:45:16
# 127262                                NaN 2007-02-02 09:07:04
# 127263                                NaN 2007-02-02 09:06:40
#
#         planned_expiration_datetime     funded_datetime  dispursal_datetime  \
# 25766           2016-04-06 03:30:06 2016-03-07 03:45:55 2016-02-03 08:00:00
# 126589                          NaT 2007-04-10 17:24:51 2007-04-24 17:24:51
# 126595                          NaT 2007-04-10 16:52:42 2007-04-24 16:52:42
# 127262                          NaT 2007-02-02 10:15:54 2007-02-16 10:15:54
# 127263                          NaT 2007-02-02 10:15:53 2007-02-16 10:15:53
#
#        number_of_loans dispersal_date posted_year
# 25766                1     2016-02-03        2016
# 126589               1     2007-04-24        2007
# 126595               1     2007-04-24        2007
# 127262               1     2007-02-16        2007
# 127263               1     2007-02-16        2007
#
# [5 rows x 83 columns]

# %% [markdown]
# ## Step 3 d: How does the loan amount vary by location?

# %% [markdown]
# ## Step 3 e: How does the average loan amount vary over time

# %% [markdown]
# ## Step 3 f: Are women asking for lower loan amounts than men?
